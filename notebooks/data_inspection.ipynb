# %% [markdown]
# # Data Loading

# %%
import cv2
import os

path = "data/Muppets-02-01-01.avi"

# --- Check file exists ---
if not os.path.exists(path):
    raise FileNotFoundError(f"File not found: {path}")

cap = cv2.VideoCapture(path)

# --- Check if OpenCV opened the file ---
if not cap.isOpened():
    raise RuntimeError("OpenCV cannot open the video. Codec may be unsupported.")

# --- Basic properties ---
fps = cap.get(cv2.CAP_PROP_FPS)
w   = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
h   = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
n   = cap.get(cv2.CAP_PROP_FRAME_COUNT)
fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))

print("FPS:", fps)
print(f"Resolution: {w} x {h}")
print("Frames:", n)
print("FourCC code:", fourcc)

# --- Try multiple reads (some AVIs fail on first read) ---
frame = None
success = False

for i in range(5):
    ret, frame = cap.read()
    print(f"Read attempt {i}, ret={ret}, frame={None if frame is None else frame.shape}")
    if ret and frame is not None:
        success = True
        break

if not success:
    raise RuntimeError("OpenCV could not decode any frame from this AVI file.")

print("Final frame shape:", frame.shape)
# Out:
# FPS: 25.0
# Resolution: 720.0 x 544.0
# Frames: 38682.0
# FourCC code: 877677894
# Read attempt 0, ret=True, frame=(544, 720, 3)
# Final frame shape: (544, 720, 3)
# [ WARN:0@53.990] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34145.557529 ms
# [ WARN:0@53.990] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34148.200876 ms
# [ WARN:0@53.990] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34148.275666 ms
# [ WARN:0@53.991] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34148.648114 ms
# [ WARN:0@53.991] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34148.672363 ms
# [ WARN:0@53.991] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34148.685696 ms
# [ WARN:0@54.020] global cap_ffmpeg_impl.hpp:453 _opencv_ffmpeg_interrupt_callback Stream timeout triggered after 34177.590891 ms
